# %%
import csv
import matplotlib.pyplot as plt

# %%
f = open('gender.csv')

data = csv.reader(f)

male = []
female = []

name = input("찾고 싶은 지역의 이름을 알려주세요.")

for row in data:
    if name in row[0]:
        for i in row[3:104]:
            male.append(-int(i.replace(',','')))
        for i in row[106:]:
            female.append(int(i.replace(',','')))
        break
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

plt.title(name + ' 지역의 인구 구조')
plt.barh(range(101),male, color = 'blue', label = '남성')
plt.barh(range(101),female, color = 'red', label = '여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요.제주특별자치도

# %% [markdown]
# ## pie() 함수 사용

# %%
plt.rc('font', family = 'Malgun Gothic')
size = [2441,2312,1031,1233]
label = ['A형', 'B형', 'O형', 'AB형']
#color data
#https://matplotlib.org/stable/gallery/color/named_colors.html
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
#autopct 소숫점 아래 둘째자리에서 반올림한 값 표시 (첫번째 소수점 표시)
#explode 돌출 효과
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))

plt.legend()
plt.show()

# %% [markdown]
# ## 제주도의 성별 인구 비율 표현 -  pie() 함수 사용

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)

size = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')

for row in data:
    if name in row[0]:
        f = 0
        m = 0
        for i in range(101):
            m += int(row[i+3].replace(',',''))
            f += int(row[i+106].replace(',',''))
        break
size.append(m)
size.append(f)

print(size)
# Out:
# 찾고 싶은 지역의 이름을 알려주세요: 부산광역시
# [1689253, 1746977]

# %%
plt.rc('font', family = 'Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
#startangle 파이 차트의 시작 각도를 정해준다.
plt.pie(size, labels=['남', '여'], autopct='%.1f%%', colors=color, startangle=90)
plt.title(name + '지역의 남녀 성별 비율')
plt.show()
